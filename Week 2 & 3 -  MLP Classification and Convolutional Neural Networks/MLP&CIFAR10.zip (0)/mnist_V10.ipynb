# %% [markdown]
# ### INTRODUCTION - This is an extension of previous mnist_v7 model for image classification with neural networks. It is a sequential model with one input layer, two hidden layers having consecutive dropout layers and an output layer. Here, batch size is increased from 256 to 512.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# network and training
EPOCHS = 20
BATCH_SIZE = 512
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# %%
# Percent of neurons to be ignored in dropout
DROPOUT = 0.3

# %%
# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly 
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784

# %%
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

# %%
#build the model
model = tf.keras.models.Sequential()

# %%
model.add(keras.layers.Dense(N_HIDDEN,
    input_shape=(RESHAPED,),
    name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
    name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
    name='dense_layer_3', activation='softmax'))

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# ...
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the model
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training the moodel
model.fit(X_train, Y_train,
        batch_size=BATCH_SIZE, epochs=EPOCHS,
        verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 1s 5ms/step - loss: 0.8303 - accuracy: 0.7430 - val_loss: 0.2743 - val_accuracy: 0.9195
# Epoch 2/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.3344 - accuracy: 0.9011 - val_loss: 0.1920 - val_accuracy: 0.9430
# Epoch 3/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.9264 - val_loss: 0.1591 - val_accuracy: 0.9537
# Epoch 4/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9379 - val_loss: 0.1415 - val_accuracy: 0.9563
# Epoch 5/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9475 - val_loss: 0.1234 - val_accuracy: 0.9632
# Epoch 6/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.1649 - accuracy: 0.9502 - val_loss: 0.1133 - val_accuracy: 0.9654
# Epoch 7/20
# ...

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0774 - accuracy: 0.9764
# Test accuracy: 0.9764000177383423

# %%
# making prediction
predictions = model.predict(X_test)
