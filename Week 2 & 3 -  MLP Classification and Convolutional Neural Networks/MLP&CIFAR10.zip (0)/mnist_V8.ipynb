# %% [markdown]
# ### INTRODUCTION - This is an extension of previous mnist_v7 model for image classification with neural networks. It is a sequential model with one input layer, two hidden layers having consecutive dropout layers and an output layer. Here, 'SGD' optimizer is set with a very specific learning rate, which remains constant throughout the training process of model.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ### In this keras optimizers are introduced. Stochastic Gradient Descent (SGD) is imported from keras optimizers and optimizer is set to SGD which later is used in compilation.
# ### Keras has its own optimizers. This imports Stochastic gradient descent (SGD) from optimizers API.

# %%
from tensorflow.keras.optimizers import SGD

# %%
# network and training
EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3   # Percent of neurons to be ignored in dropout

# %% [markdown]
# ### Lr is learning rate. A Tensor, floating point value, or a schedule that is a tf.keras.optimizers.schedules.LearningRateSchedule, or a callable that takes no arguments and returns the actual value to use. The learning rate defaults to 0.01.

# %%
OPTMIZER = SGD(lr=0.001)

# %%
# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly 
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %%
#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
    input_shape=(RESHAPED,),
    name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
    name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
    name='dense_layer_3', activation='softmax'))

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# ...
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the model
model.compile(optimizer=OPTMIZER, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training the moodel
model.fit(X_train, Y_train,
        batch_size=BATCH_SIZE, epochs=EPOCHS,
        verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 188/188 [==============================] - 1s 4ms/step - loss: 2.3590 - accuracy: 0.0926 - val_loss: 2.2706 - val_accuracy: 0.1134
# Epoch 2/20
# 188/188 [==============================] - 1s 3ms/step - loss: 2.2771 - accuracy: 0.1406 - val_loss: 2.1918 - val_accuracy: 0.2496
# Epoch 3/20
# 188/188 [==============================] - 1s 3ms/step - loss: 2.2090 - accuracy: 0.1995 - val_loss: 2.1195 - val_accuracy: 0.3876
# Epoch 4/20
# 188/188 [==============================] - 1s 3ms/step - loss: 2.1440 - accuracy: 0.2591 - val_loss: 2.0486 - val_accuracy: 0.4790
# Epoch 5/20
# 188/188 [==============================] - 1s 3ms/step - loss: 2.0799 - accuracy: 0.3151 - val_loss: 1.9763 - val_accuracy: 0.5411
# Epoch 6/20
# 188/188 [==============================] - 1s 3ms/step - loss: 2.0159 - accuracy: 0.3618 - val_loss: 1.9017 - val_accuracy: 0.5870
# Epoch 7/20
# ...

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9481 - accuracy: 0.8133
# Test accuracy: 0.8133000135421753

# %%
# making prediction
predictions = model.predict(X_test)

# %% [markdown]
# **Observation**
#
# Making the learning rate 0.001 decreases the performance of model.
